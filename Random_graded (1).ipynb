# %%
import pandas as pd
import os
os.chdir("G:\\python\\Datasets\\")  #to set working directory

# %%
os.getcwd()
# Out:
# 'G:\\python\\Datasets'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import json
# %matplotlib inline

with open("G:\\python\\Datasets\\amsterdam.json") as datafile:
  data = json.load(datafile)
dat = pd.DataFrame(data)

# %%
dat.shape
# Out:
# (15181, 13)

# %%
dat.head()
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 0                     1.0             6        1.0       2.0                1
# 1                     1.0             2        1.0       1.0                1
# 10                    1.0             2        1.0       1.0                1
# 100                   1.0             5        1.0       4.0                1
# 1000                  1.0             1        1.0       1.0                1
#
#       minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 0                  3                  4                               1
# 1                  2                 17                               1
# 10                 3                  0                               1
# 100                5                  2                               1
# 1000               1                 32                               1
#
# ...

# %%
dat.isnull().sum()
# Out:
# host_listings_count                3
# accommodates                       0
# bathrooms                         18
# bedrooms                          12
# guests_included                    0
# minimum_nights                     0
# number_of_reviews                  0
# calculated_host_listings_count     0
# price                              0
# latitude                           0
# longitude                          0
# room_type                          0
# instant_bookable                   0
# dtype: int64

# %%
dat.dtypes
# Out:
# host_listings_count               float64
# accommodates                        int64
# bathrooms                         float64
# bedrooms                          float64
# guests_included                     int64
# minimum_nights                      int64
# number_of_reviews                   int64
# calculated_host_listings_count      int64
# price                              object
# latitude                          float64
# longitude                         float64
# room_type                          object
# instant_bookable                   object
# dtype: object

# %%
dat['price'] = dat['price'].str.replace('$', '')

# %%
dat['price']=dat['price'].str.replace(",","").astype("float64")

# %%
dat['price'].dtypes
# Out:
# dtype('float64')

# %%
dat['price'].mean()
# Out:
# 134.79922271260128

# %%
dat['bathrooms'].describe()
# Out:
# count    15163.000000
# mean         1.122832
# std          0.356547
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          8.000000
# Name: bathrooms, dtype: float64

# %%
dat['price'].describe()
# Out:
# count    15181.000000
# mean       134.799223
# std         85.751273
# min         19.000000
# 25%         90.000000
# 50%        118.000000
# 75%        150.000000
# max       3142.000000
# Name: price, dtype: float64

# %%
dat['price'].max()
# Out:
# 3142.0

# %%
dat.price.quantile(0.99)
# Out:
# 440.0

# %%
dat[dat['price']>dat['price'].quantile(0.99)].shape[0]
dat['price'].quantile(0.90)
# Out:
# 220.0

# %%
dat.isnull().sum()
# Out:
# host_listings_count                3
# accommodates                       0
# bathrooms                         18
# bedrooms                          12
# guests_included                    0
# minimum_nights                     0
# number_of_reviews                  0
# calculated_host_listings_count     0
# price                              0
# latitude                           0
# longitude                          0
# room_type                          0
# instant_bookable                   0
# dtype: int64

# %%
d1=dat.dropna()

# %%
d1.shape
# Out:
# (15148, 13)

# %%
d1.isnull().sum()
# Out:
# host_listings_count               0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# guests_included                   0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# price                             0
# latitude                          0
# longitude                         0
# room_type                         0
# instant_bookable                  0
# dtype: int64

# %%
d1.dtypes
# Out:
# host_listings_count               float64
# accommodates                        int64
# bathrooms                         float64
# bedrooms                          float64
# guests_included                     int64
# minimum_nights                      int64
# number_of_reviews                   int64
# calculated_host_listings_count      int64
# price                             float64
# latitude                          float64
# longitude                         float64
# room_type                          object
# instant_bookable                   object
# dtype: object

# %%
dat['lat']=52.379189

# %%
dat['long']=4.899431

# %%
dat.isnull().sum()
# Out:
# host_listings_count                3
# accommodates                       0
# bathrooms                         18
# bedrooms                          12
# guests_included                    0
# minimum_nights                     0
# number_of_reviews                  0
# calculated_host_listings_count     0
# price                              0
# latitude                           0
# longitude                          0
# room_type                          0
# instant_bookable                   0
# lat                                0
# long                               0
# dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 0                     1.0             6        1.0       2.0                1
# 1                     1.0             2        1.0       1.0                1
# 10                    1.0             2        1.0       1.0                1
# 100                   1.0             5        1.0       4.0                1
# 1000                  1.0             1        1.0       1.0                1
#
#       minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 0                  3                  4                               1
# 1                  2                 17                               1
# 10                 3                  0                               1
# 100                5                  2                               1
# 1000               1                 32                               1
#
# ...

# %%
from math import radians, cos, sin, asin, sqrt
def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    km = 6367 * c
    return km


for index, row in dat.iterrows():
    dat.loc[index, 'distance'] = haversine(row['long'], row['lat'], row['longitude'], row['latitude'])

# %%
dat.dtypes
# Out:
# host_listings_count               float64
# accommodates                        int64
# bathrooms                         float64
# bedrooms                          float64
# guests_included                     int64
# minimum_nights                      int64
# number_of_reviews                   int64
# calculated_host_listings_count      int64
# price                             float64
# latitude                          float64
# longitude                         float64
# room_type                          object
# instant_bookable                   object
# lat                               float64
# long                              float64
# distance                          float64
# dtype: object

# %%
dat.head()
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 0                     1.0             6        1.0       2.0                1
# 1                     1.0             2        1.0       1.0                1
# 10                    1.0             2        1.0       1.0                1
# 100                   1.0             5        1.0       4.0                1
# 1000                  1.0             1        1.0       1.0                1
#
#       minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 0                  3                  4                               1
# 1                  2                 17                               1
# 10                 3                  0                               1
# 100                5                  2                               1
# 1000               1                 32                               1
#
# ...

# %%
df=dat.dropna()

# %%
df.shape
# Out:
# (15148, 16)

# %%
df['distance'].describe()
# Out:
# count    15148.000000
# mean         2.990385
# std          1.609425
# min          0.115801
# 25%          1.939991
# 50%          2.836397
# 75%          3.573652
# max         11.842162
# Name: distance, dtype: float64

# %%
df.isnull().sum()
# Out:
# host_listings_count               0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# guests_included                   0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# price                             0
# latitude                          0
# longitude                         0
# room_type                         0
# instant_bookable                  0
# lat                               0
# long                              0
# distance                          0
# dtype: int64

# %%
df.sort_values('distance')
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 3158                  1.0             2        1.5       1.0                1
# 3168                  1.0             4        1.0       1.0                1
# 2639                  1.0             4        1.0       1.0                2
# 3010                  4.0             2        1.0       1.0                1
# 1860                  1.0             2        1.0       1.0                1
# 1447                  4.0             2        1.0       1.0                1
# 3064                  2.0             2        1.0       1.0                1
# 1660                  1.0             2        1.0       1.0                1
# 1481                  1.0             2        1.0       1.0                1
# 1939                  1.0             4        1.0       1.0                2
# 2536                  3.0             4        1.0       1.0                1
# ...

# %%
df.sort_values(by=['distance'], ascending=True)
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 3158                  1.0             2        1.5       1.0                1
# 3168                  1.0             4        1.0       1.0                1
# 2639                  1.0             4        1.0       1.0                2
# 3010                  4.0             2        1.0       1.0                1
# 1860                  1.0             2        1.0       1.0                1
# 1447                  4.0             2        1.0       1.0                1
# 3064                  2.0             2        1.0       1.0                1
# 1660                  1.0             2        1.0       1.0                1
# 1481                  1.0             2        1.0       1.0                1
# 1939                  1.0             4        1.0       1.0                2
# 2536                  3.0             4        1.0       1.0                1
# ...

# %%
ss=d1.groupby('room_type')['distance'].mean().sort_values(ascending=False)

# %%
df.query("room_type=='Private room' & distance>1.0")[['price']].mean()
# Out:
# price    85.119558
# dtype: float64

# %%
X=df.drop("price",axis=1)

# %%
X.columns
# Out:
# Index(['host_listings_count', 'accommodates', 'bathrooms', 'bedrooms',
#        'guests_included', 'minimum_nights', 'number_of_reviews',
#        'calculated_host_listings_count', 'latitude', 'longitude', 'room_type',
#        'instant_bookable', 'lat', 'long', 'distance'],
#       dtype='object')

# %%
X=pd.get_dummies(X)

# %%
X.columns
# Out:
# Index(['host_listings_count', 'accommodates', 'bathrooms', 'bedrooms',
#        'guests_included', 'minimum_nights', 'number_of_reviews',
#        'calculated_host_listings_count', 'latitude', 'longitude', 'lat',
#        'long', 'distance', 'room_type_Entire home/apt',
#        'room_type_Private room', 'room_type_Shared room', 'instant_bookable_f',
#        'instant_bookable_t'],
#       dtype='object')

# %%
X.shape
# Out:
# (15148, 18)

# %%
y=df['price']

# %%
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test=model_selection.train_test_split(X,y,test_size=0.3,random_state=200)

# %%
X_train.isnull().sum()
# Out:
# host_listings_count               0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# guests_included                   0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# latitude                          0
# longitude                         0
# lat                               0
# long                              0
# distance                          0
# room_type_Entire home/apt         0
# room_type_Private room            0
# room_type_Shared room             0
# instant_bookable_f                0
# instant_bookable_t                0
# dtype: int64

# %%
X_train.shape
# Out:
# (10603, 18)

# %%
from sklearn.ensemble import RandomForestRegressor
reg=RandomForestRegressor(n_estimators=50,max_depth=5,max_features='sqrt',oob_score=True,random_state=1)
reg.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=5,
#            max_features='sqrt', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=1,
#            oob_score=True, random_state=1, verbose=0, warm_start=False)

# %%
reg.score(X_test,y_test)
# Out:
# 0.34944128800877006

# %%
reg.oob_score_# same as Rsquare in regression
# Out:
# 0.4027672099188436

# %%
from sklearn import metrics
metrics.mean_squared_error(y_test,reg.predict(X_test))
# Out:
# 5237.7475249283025

# %%
#Tuning the n_estimators
for i in range(30,610,10):
    reg=RandomForestRegressor(n_estimators=i,max_depth=5,max_features='sqrt',oob_score=True,random_state=200)
    reg.fit(X_train,y_train)
    oob=reg.oob_score_
    print('For n_estimators = '+str(i))
    print('OOB score is '+str(oob))
    print('************************')
# Out:
# For n_estimators = 30
# OOB score is 0.40100670473746536
# ************************
# For n_estimators = 40
# OOB score is 0.4052066956293101
# ************************
# For n_estimators = 50
# OOB score is 0.40894755092237345
# ************************
# For n_estimators = 60
# OOB score is 0.4098786212565013
# ************************
# For n_estimators = 70
# OOB score is 0.4101408472201481
# ************************
# For n_estimators = 80
# OOB score is 0.4122228840792982
# ************************
# For n_estimators = 90
# OOB score is 0.41373344899369546
# ************************
# For n_estimators = 100
# OOB score is 0.41323839059033596
# ************************
# For n_estimators = 110
# OOB score is 0.414076811187823
# ************************
# For n_estimators = 120
# OOB score is 0.4159715121138906
# ************************
# For n_estimators = 130
# OOB score is 0.4147131215064729
# ************************
# For n_estimators = 140
# ...

# %%
reg=RandomForestRegressor(n_estimators=470,max_depth=5,max_features='sqrt',oob_score=True,random_state=200)
reg.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=5,
#            max_features='sqrt', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=470, n_jobs=1,
#            oob_score=True, random_state=200, verbose=0, warm_start=False)

# %%
reg.oob_score_
# Out:
# 0.4159896111425111

# %%
reg.score(X_test,y_test)
# Out:
# 0.3550154785694102

# %%
reg.feature_importances_
# Out:
# array([1.09619120e-02, 2.83267285e-01, 1.12887511e-01, 2.18848914e-01,
#        9.34268577e-02, 3.40008795e-02, 1.22188726e-02, 1.54704067e-02,
#        1.81423135e-02, 3.12625059e-02, 0.00000000e+00, 0.00000000e+00,
#        6.18187897e-02, 5.42976792e-02, 4.99826669e-02, 2.00131772e-04,
#        1.76042876e-03, 1.45284607e-03])

# %%
# We can extract feature importance from each tree then take a mean for all trees
import numpy as np
mp=[]
for i in reg.estimators_:
    mp.append(i.feature_importances_)#finding feature impt in each tree
#imp
mp=np.mean(mp,axis=0)#row wise axis=0
#imp

# %%
feature_importance=pd.Series(mp,index=X_train.columns.tolist()).sort_values(ascending=False)
feature_importance
# Out:
# accommodates                      0.283267
# bedrooms                          0.218849
# bathrooms                         0.112888
# guests_included                   0.093427
# distance                          0.061819
# room_type_Entire home/apt         0.054298
# room_type_Private room            0.049983
# minimum_nights                    0.034001
# longitude                         0.031263
# latitude                          0.018142
# calculated_host_listings_count    0.015470
# number_of_reviews                 0.012219
# host_listings_count               0.010962
# instant_bookable_f                0.001760
# instant_bookable_t                0.001453
# room_type_Shared room             0.000200
# lat                               0.000000
# long                              0.000000
# dtype: float64
