# %%
import pandas as pd
import os
os.chdir("G:\\python\\Datasets\\")  #to set working directory

# %%
os.getcwd()
# Out:
# 'G:\\python\\Datasets'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import json
# %matplotlib inline

with open("G:\\python\\Datasets\\amsterdam.json") as datafile:
  data = json.load(datafile)
dat = pd.DataFrame(data)

# %%
dat.shape
# Out:
# (15181, 13)

# %%
dat.head()
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 0                     1.0             6        1.0       2.0                1
# 1                     1.0             2        1.0       1.0                1
# 10                    1.0             2        1.0       1.0                1
# 100                   1.0             5        1.0       4.0                1
# 1000                  1.0             1        1.0       1.0                1
#
#       minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 0                  3                  4                               1
# 1                  2                 17                               1
# 10                 3                  0                               1
# 100                5                  2                               1
# 1000               1                 32                               1
#
# ...

# %%
dat.isnull().sum()
# Out:
# host_listings_count                3
# accommodates                       0
# bathrooms                         18
# bedrooms                          12
# guests_included                    0
# minimum_nights                     0
# number_of_reviews                  0
# calculated_host_listings_count     0
# price                              0
# latitude                           0
# longitude                          0
# room_type                          0
# instant_bookable                   0
# dtype: int64

# %%
dat.dtypes
# Out:
# host_listings_count               float64
# accommodates                        int64
# bathrooms                         float64
# bedrooms                          float64
# guests_included                     int64
# minimum_nights                      int64
# number_of_reviews                   int64
# calculated_host_listings_count      int64
# price                              object
# latitude                          float64
# longitude                         float64
# room_type                          object
# instant_bookable                   object
# dtype: object

# %%
dat['price'] = dat['price'].str.replace('$', '')

# %%
dat['price']=dat['price'].str.replace(",","").astype("float64")

# %%
dat['price'].dtypes
# Out:
# dtype('float64')

# %%
dat['price'].mean()
# Out:
# 134.79922271260128

# %%
dat['bathrooms'].describe()
# Out:
# count    15163.000000
# mean         1.122832
# std          0.356547
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          8.000000
# Name: bathrooms, dtype: float64

# %%
dat['price'].describe()
# Out:
# count    15181.000000
# mean       134.799223
# std         85.751273
# min         19.000000
# 25%         90.000000
# 50%        118.000000
# 75%        150.000000
# max       3142.000000
# Name: price, dtype: float64

# %%
dat['price'].max()
# Out:
# 3142.0

# %%
dat.price.quantile(0.99)
# Out:
# 440.0

# %%
dat[dat['price']>dat['price'].quantile(0.99)].shape[0]
dat['price'].quantile(0.90)
# Out:
# 220.0

# %%
dat.isnull().sum()
# Out:
# host_listings_count                3
# accommodates                       0
# bathrooms                         18
# bedrooms                          12
# guests_included                    0
# minimum_nights                     0
# number_of_reviews                  0
# calculated_host_listings_count     0
# price                              0
# latitude                           0
# longitude                          0
# room_type                          0
# instant_bookable                   0
# dtype: int64

# %%
d1=dat.dropna()

# %%
d1.shape
# Out:
# (15148, 13)

# %%
d1.isnull().sum()
# Out:
# host_listings_count               0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# guests_included                   0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# price                             0
# latitude                          0
# longitude                         0
# room_type                         0
# instant_bookable                  0
# lat                               0
# long                              0
# distance                          0
# dtype: int64

# %%
d1.dtypes
# Out:
# host_listings_count               float64
# accommodates                        int64
# bathrooms                         float64
# bedrooms                          float64
# guests_included                     int64
# minimum_nights                      int64
# number_of_reviews                   int64
# calculated_host_listings_count      int64
# price                             float64
# latitude                          float64
# longitude                         float64
# room_type                          object
# instant_bookable                   object
# dtype: object

# %%
d1['lat']=52.379189
# Out:
# C:\Users\Rashmi HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
d1['long']=4.899431
# Out:
# C:\Users\Rashmi HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
d1.head()
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 0                     1.0             6        1.0       2.0                1
# 1                     1.0             2        1.0       1.0                1
# 10                    1.0             2        1.0       1.0                1
# 100                   1.0             5        1.0       4.0                1
# 1000                  1.0             1        1.0       1.0                1
#
#       minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 0                  3                  4                               1
# 1                  2                 17                               1
# 10                 3                  0                               1
# 100                5                  2                               1
# 1000               1                 32                               1
#
# ...

# %%
from math import radians, cos, sin, asin, sqrt
def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    km = 6367 * c
    return km


for index, row in d1.iterrows():
    d1.loc[index, 'distance'] = haversine(row['long'], row['lat'], row['longitude'], row['latitude'])

# %%
d1.dtypes

# %%
d1.head()
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 0                     1.0             6        1.0       2.0                1
# 1                     1.0             2        1.0       1.0                1
# 10                    1.0             2        1.0       1.0                1
# 100                   1.0             5        1.0       4.0                1
# 1000                  1.0             1        1.0       1.0                1
#
#       minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 0                  3                  4                               1
# 1                  2                 17                               1
# 10                 3                  0                               1
# 100                5                  2                               1
# 1000               1                 32                               1
#
# ...

# %%
d1.to_csv("am.csv")

# %%
d1['distance'].describe()
# Out:
# count    15181.000000
# mean         2.989669
# std          1.609333
# min          0.115801
# 25%          1.939552
# 50%          2.834542
# 75%          3.573343
# max         11.842162
# Name: distance, dtype: float64

# %%
d1.sort_values('distance')
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 3158                  1.0             2        1.5       1.0                1
# 3168                  1.0             4        1.0       1.0                1
# 2639                  1.0             4        1.0       1.0                2
# 3010                  4.0             2        1.0       1.0                1
# 1860                  1.0             2        1.0       1.0                1
# 1447                  4.0             2        1.0       1.0                1
# 3064                  2.0             2        1.0       1.0                1
# 1660                  1.0             2        1.0       1.0                1
# 1481                  1.0             2        1.0       1.0                1
# 1939                  1.0             4        1.0       1.0                2
# 2536                  3.0             4        1.0       1.0                1
# ...

# %%
d1.sort_values(by=['distance'], ascending=True)
# Out:
#       host_listings_count  accommodates  bathrooms  bedrooms  guests_included  \
# 3158                  1.0             2        1.5       1.0                1
# 3168                  1.0             4        1.0       1.0                1
# 2639                  1.0             4        1.0       1.0                2
# 3010                  4.0             2        1.0       1.0                1
# 1860                  1.0             2        1.0       1.0                1
# 1447                  4.0             2        1.0       1.0                1
# 3064                  2.0             2        1.0       1.0                1
# 1660                  1.0             2        1.0       1.0                1
# 1481                  1.0             2        1.0       1.0                1
# 1939                  1.0             4        1.0       1.0                2
# 2536                  3.0             4        1.0       1.0                1
# ...

# %%
ss=d1.groupby('room_type')['distance'].mean().sort_values(ascending=False)

# %%
d1.query("room_type=='Private room' & distance>1.0")[['price']].mean()
# Out:
# price    85.126123
# dtype: float64

# %%
X=d1.drop("price",axis=1)

# %%
X.columns
# Out:
# Index(['host_listings_count', 'accommodates', 'bathrooms', 'bedrooms',
#        'guests_included', 'minimum_nights', 'number_of_reviews',
#        'calculated_host_listings_count', 'latitude', 'longitude', 'room_type',
#        'instant_bookable', 'lat', 'long', 'distance'],
#       dtype='object')

# %%
X=pd.get_dummies(X)

# %%
X.columns
# Out:
# Index(['host_listings_count', 'accommodates', 'bathrooms', 'bedrooms',
#        'guests_included', 'minimum_nights', 'number_of_reviews',
#        'calculated_host_listings_count', 'latitude', 'longitude', 'lat',
#        'long', 'distance', 'room_type_Entire home/apt',
#        'room_type_Private room', 'room_type_Shared room', 'instant_bookable_f',
#        'instant_bookable_t'],
#       dtype='object')

# %%
X.shape
# Out:
# (15181, 18)

# %%
y=d1['price']

# %%
import sklearn.model_selection as model_selection

X_train,X_test,y_train,y_test=model_selection.train_test_split(X,y,test_size=0.3,random_state=200)

# %%
X_train.isnull().sum()
# Out:
# host_listings_count                3
# accommodates                       0
# bathrooms                         11
# bedrooms                           9
# guests_included                    0
# minimum_nights                     0
# number_of_reviews                  0
# calculated_host_listings_count     0
# latitude                           0
# longitude                          0
# lat                                0
# long                               0
# distance                           0
# room_type_Entire home/apt          0
# room_type_Private room             0
# room_type_Shared room              0
# instant_bookable_f                 0
# instant_bookable_t                 0
# dtype: int64

# %%
X_test.shape
# Out:
# (4555, 18)

# %%
from sklearn.ensemble import RandomForestRegressor
reg=RandomForestRegressor(n_estimators=50,max_depth=5,max_features='sqrt',oob_score=True,random_state=1)
reg.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-e0d70fcf439f> in <module>()
#       1 from sklearn.ensemble import RandomForestRegressor
#       2 reg=RandomForestRegressor(n_estimators=50,max_depth=5,max_features='sqrt',oob_score=True,random_state=1)
# ----> 3 reg.fit(X_train,y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     249         if sample_weight is not None:
#
# ...
